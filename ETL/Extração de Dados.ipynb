# %%
import pandas as pd
 
file = open(r"C:\Users\luan.gomes\OneDrive - VIKSERVICES OUTSOURCING S.A\Documentos\Python\ETL\AAPL.csv", 'r', encoding="UTF-8")
print(file.readlines())
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume\n', '2023-03-01,146.830002,147.229996,145.009995,145.309998,144.538498,55479000\n', '2023-03-02,144.380005,146.710007,143.899994,145.910004,145.135330,52238100\n', '2023-03-03,148.039993,151.110001,147.330002,151.029999,150.228134,70732300\n', '2023-03-06,153.789993,156.300003,153.460007,153.830002,153.013275,87558000\n', '2023-03-07,153.699997,154.029999,151.130005,151.600006,150.795120,56182000\n', '2023-03-08,152.809998,153.470001,151.830002,152.869995,152.058365,47204800\n', '2023-03-09,153.559998,154.539993,150.229996,150.589996,149.790466,53833600\n', '2023-03-10,150.210007,150.940002,147.610001,148.500000,147.711563,68572400\n', '2023-03-13,147.809998,153.139999,147.699997,150.470001,149.671112,84457100\n', '2023-03-14,151.279999,153.399994,150.100006,152.589996,151.779831,73695900\n', '2023-03-15,151.190002,153.250000,149.919998,152.990005,152.177734,77167900\n', '2023-03-16,152.160004,156.460007,151.639999,155.850006,155.022537,761
# ...

# %%
pd.Series([10, 9, 8, 7, 6])
# Out:
# 0    10
# 1     9
# 2     8
# 3     7
# 4     6
# dtype: int64

# %%
notas = pd.Series([10, 9, 8, 7, 6])
notas.mean()
# Out:
# 8.0

# %%
notas.sum()
# Out:
# 40

# %%
notas.std()
# Out:
# 1.5811388300841898

# %%
df = pd.DataFrame({"Alunos":["Alfredo", "Abel", "Henrique", "Julia", "Lana"], "Faltas": [1, 8, 4, 0, 2],
                  "Prova": [10, 9.8, 4.5, 8.6, 1.4]})

# %%
df.iloc[0]
# Out:
# Alunos    Alfredo
# Faltas          1
# Prova        10.0
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['Alunos', 'Faltas', 'Prova'], dtype='object')

# %%
df.dtypes
# Out:
# Alunos     object
# Faltas      int64
# Prova     float64
# dtype: object

# %%
df
# Out:
#      Alunos  Faltas  Prova
# 0   Alfredo       1   10.0
# 1      Abel       8    9.8
# 2  Henrique       4    4.5
# 3     Julia       0    8.6
# 4      Lana       2    1.4

# %%
df[df["Prova"] > 8]
# Out:
#     Alunos  Faltas  Prova
# 0  Alfredo       1   10.0
# 1     Abel       8    9.8
# 3    Julia       0    8.6

# %%
apple = pd.read_csv(r"C:\Users\luan.gomes\OneDrive - VIKSERVICES OUTSOURCING S.A\Documentos\Python\ETL\AAPL.csv", sep=",")

# %%
apple
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-03-01  146.830002  147.229996  145.009995  145.309998  144.538498
# 1    2023-03-02  144.380005  146.710007  143.899994  145.910004  145.135330
# 2    2023-03-03  148.039993  151.110001  147.330002  151.029999  150.228134
# 3    2023-03-06  153.789993  156.300003  153.460007  153.830002  153.013275
# 4    2023-03-07  153.699997  154.029999  151.130005  151.600006  150.795120
# ..          ...         ...         ...         ...         ...         ...
# 248  2024-02-26  182.240005  182.759995  180.649994  181.160004  181.160004
# 249  2024-02-27  181.100006  183.919998  179.559998  182.630005  182.630005
# 250  2024-02-28  182.509995  183.119995  180.130005  181.419998  181.419998
# 251  2024-02-29  181.270004  182.570007  179.529999  180.750000  180.750000
# 252  2024-03-01  179.679993  180.529999  177.380005  179.774994  179.774994
#
#         Volume
# 0     55479000
# 1     52238100
# ...

# %%
apple.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2023-03-01  146.830002  147.229996  145.009995  145.309998  144.538498
# 1  2023-03-02  144.380005  146.710007  143.899994  145.910004  145.135330
# 2  2023-03-03  148.039993  151.110001  147.330002  151.029999  150.228134
# 3  2023-03-06  153.789993  156.300003  153.460007  153.830002  153.013275
# 4  2023-03-07  153.699997  154.029999  151.130005  151.600006  150.795120
# 5  2023-03-08  152.809998  153.470001  151.830002  152.869995  152.058365
# 6  2023-03-09  153.559998  154.539993  150.229996  150.589996  149.790466
# 7  2023-03-10  150.210007  150.940002  147.610001  148.500000  147.711563
# 8  2023-03-13  147.809998  153.139999  147.699997  150.470001  149.671112
# 9  2023-03-14  151.279999  153.399994  150.100006  152.589996  151.779831
#
#      Volume
# 0  55479000
# 1  52238100
# 2  70732300
# 3  87558000
# 4  56182000
# 5  47204800
# 6  53833600
# 7  68572400
# 8  84457100
# 9  73695900

# %%
apple.tail(7)[["Adj Close"]]
# Out:
#       Adj Close
# 246  184.369995
# 247  182.520004
# 248  181.160004
# 249  182.630005
# 250  181.419998
# 251  180.750000
# 252  179.774994

# %%
apple.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  253.000000  253.000000  253.000000  253.000000  253.000000
# mean   179.130159  180.615336  177.808696  179.331087  178.805796
# std     11.904589   11.714228   11.836280   11.738739   11.879113
# min    144.380005  146.710007  143.899994  145.309998  144.538498
# 25%    172.410004  173.899994  171.279999  172.880005  172.309540
# 50%    180.089996  181.929993  178.330002  180.570007  179.859726
# 75%    189.259995  189.990005  187.610001  189.300003  188.850006
# max    198.020004  199.619995  197.000000  198.110001  197.857529
#
#              Volume
# count  2.530000e+02
# mean   5.712606e+07
# std    1.665263e+07
# min    2.404830e+07
# 25%    4.679290e+07
# 50%    5.307930e+07
# 75%    6.230330e+07
# max    1.365952e+08

# %%
tabela = pd.read_html("https://www.contextures.com/xlsampledata01.html")

# %%
tabela[1]
# Out:
#              0        1         2        3      4         5        6
# 0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
# 1     1/6/2020     East     Jones   Pencil     95      1.99   189.05
# 2    1/23/2020  Central    Kivell   Binder     50     19.99   999.50
# 3     2/9/2020  Central   Jardine   Pencil     36      4.99   179.64
# 4    2/26/2020  Central      Gill      Pen     27     19.99   539.73
# 5    3/15/2020     West   Sorvino   Pencil     56      2.99   167.44
# 6     4/1/2020     East     Jones   Binder     60      4.99   299.40
# 7    4/18/2020  Central   Andrews   Pencil     75      1.99   149.25
# 8     5/5/2020  Central   Jardine   Pencil     90      4.99   449.10
# 9    5/22/2020     West  Thompson   Pencil     32      1.99    63.68
# 10    6/8/2020     East     Jones   Binder     60      8.99   539.40
# 11   6/25/2020  Central    Morgan   Pencil     90      4.99   449.10
# 12   7/12/2020     East    Howard   Binder     29      1.99    57.71
# ...

# %%
len(tabela)
# Out:
# 2

# %%
tabela[0]
# Out:
#                                                    0
# 0  Home > Data > Sample > Sample Data Excel Sampl...
